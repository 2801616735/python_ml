# %% [markdown]
# # 泰坦尼克号生存预测
# * 通过观察数据特征，预测哪些人可以生存下来

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import datasets
# %matplotlib inline

# %% [markdown]
# ## 1、观察数据集

# %%
data_train = pd.read_csv("data/titanic/train.csv")
# 打印信息
data_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 66.2+ KB

# %%
# 数据缺失程度
data_train.groupby('Survived').count()
# Out:
#           PassengerId  Pclass  Name  Sex  Age  SibSp  Parch  Ticket  Fare  \
# Survived
# 0                 549     549   549  549  424    549    549     549   549
# 1                 342     342   342  342  290    342    342     342   342
#
#           Cabin  Embarked
# Survived
# 0            68       549
# 1           136       340

# %%
data_train.head(5)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ## 1.1、处理数据缺失问题
# * 处理数值型:
#       * 扔掉缺失数据
#       * 按某个统计量(平均值、中位数、定值等)补全
#       * 拿模型预测缺失值
# * 处理类别/文本型:
#       * 做转换处理

# %%
# 补全Age列缺失问题
def set_missing_ages(p_df):
    p_df.loc[(p_df.Age.isnull()),'Age'] =  p_df.Age.dropna().mean()
    return p_df

df = set_missing_ages(data_train)

# %%
# 归一化数据 年龄和费用一列
# 定义去均值和归一化函数
def meanAndStd(arr):
    return (arr-np.mean(arr))/np.std(arr)

import sklearn.preprocessing as preprocessing
scaler = preprocessing.StandardScaler()
scaler.fit_transform()
# ['Age']-pd['Age'].std()
# data_train['Fare_scaled'] = scaler.fit_transform(data_train['Fare'])
# Out:
# array([[-1.],
#        [ 1.]])

# %%
# 处理类别/文本型
df.loc[(pd.Cabin.notnull()),'Cabin'] = 'Yes'
df.loc[(pd.Cabin.isnull()),'Cabin'] = 'No'

train_df = df.filter(regex='Survived|Age*|SibSp|Parch|Fare')
train_df
# Out:
#      Survived        Age  SibSp  Parch      Fare
# 0           0  22.000000      1      0    7.2500
# 1           1  38.000000      1      0   71.2833
# 2           1  26.000000      0      0    7.9250
# 3           1  35.000000      1      0   53.1000
# 4           0  35.000000      0      0    8.0500
# 5           0  29.699118      0      0    8.4583
# 6           0  54.000000      0      0   51.8625
# 7           0   2.000000      3      1   21.0750
# 8           1  27.000000      0      2   11.1333
# 9           1  14.000000      1      0   30.0708
# 10          1   4.000000      1      1   16.7000
# 11          1  58.000000      0      0   26.5500
# 12          0  20.000000      0      0    8.0500
# 13          0  39.000000      1      5   31.2750
# 14          0  14.000000      0      0    7.8542
# 15          1  55.000000      0      0   16.0000
# 16          0   2.000000      4      1   29.1250
# 17          1  29.699118      0      0   13.0000
# 18          0  31.000000      1      0   18.0000
# 19          1  29.699118      0      0    7.2250
# 20          0  35.000000      0      0   26.0000
# 21          1  34.000000      0      0   13.0000
# 22          1  15.000000      0      0    8.0292
# 23          1  28.000000      0      0   35.5000
# 24          0   8.000000      3      1   21.0750
# 25          1  38.000000      1      5   31.3875
# 26          0  29.699118      0      0    7.2250
# 27          0  19.000000      3      2  263.0000
# 28          1  29.699118      0      0    7.8792
# 29          0  29.699118      0      0    7.8958
# ..        ...        ...    ...    ...       ...
# 861         0  21.000000      1      0   11.5000
# 862         1  48.000000      0      0   25.9292
# 863         0  29.699118      8      2   69.5500
# 864         0  24.000000      0      0   13.0000
# 865         1  42.000000      0      0   13.0000
# 866         1  27.000000      1      0   13.8583
# 867         0  31.000000      0      0   50.4958
# 868         0  29.699118      0      0    9.5000
# 869         1   4.000000      1      1   11.1333
# 870         0  26.000000      0      0    7.8958
# 871         1  47.000000      1      1   52.5542
# 872         0  33.000000      0      0    5.0000
# 873         0  47.000000      0      0    9.0000
# 874         1  28.000000      1      0   24.0000
# 875         1  15.000000      0      0    7.2250
# 876         0  20.000000      0      0    9.8458
# 877         0  19.000000      0      0    7.8958
# 878         0  29.699118      0      0    7.8958
# 879         1  56.000000      0      1   83.1583
# 880         1  25.000000      0      1   26.0000
# 881         0  33.000000      0      0    7.8958
# 882         0  22.000000      0      0   10.5167
# 883         0  28.000000      0      0   10.5000
# 884         0  25.000000      0      0    7.0500
# 885         0  39.000000      0      5   29.1250
# 886         0  27.000000      0      0   13.0000
# 887         1  19.000000      0      0   30.0000
# 888         0  29.699118      1      2   23.4500
# 889         1  26.000000      0      0   30.0000
# 890         0  32.000000      0      0    7.7500
#
# [891 rows x 5 columns]

# %% [markdown]
# ## 2、使用模型

# %%
Y = train_df.Survived
X = train_df[['Age','SibSp','Parch','Fare']]

from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(C=1000.0, random_state=0)
lr.fit(X, Y)
# Out:
# LogisticRegression(C=1000.0, class_weight=None, dual=False,
#           fit_intercept=True, intercept_scaling=1, max_iter=100,
#           multi_class='ovr', n_jobs=1, penalty='l2', random_state=0,
#           solver='liblinear', tol=0.0001, verbose=0, warm_start=False)

# %% [markdown]
# ## 3、预测

# %%
lr.predict([[22.000000,1,0,7.2500],[38.000000,1,0,71.2833],[58.000000,0,0,26.5500]])
# Out:
# array([0, 0, 0], dtype=int64)
